# %% [markdown]
# # **Pandas Reader**

# %%
import pandas_datareader.data as web

# %%
import datetime

# %%
start = datetime.datetime(2018,1,1)
end = datetime.datetime(2021,1,1)

# %%
fb = web.DataReader('FB','yahoo',start,end)
fb.head()
# Out:
#                   High         Low  ...    Volume   Adj Close
# Date                                ...
# 2018-01-02  181.580002  177.550003  ...  18151900  181.419998
# 2018-01-03  184.779999  181.330002  ...  16886600  184.669998
# 2018-01-04  186.210007  184.100006  ...  13880900  184.330002
# 2018-01-05  186.899994  184.929993  ...  13574500  186.850006
# 2018-01-08  188.899994  186.330002  ...  17994700  188.279999
#
# [5 rows x 6 columns]

# %%
from pandas_datareader.yahoo.options import Options as YahooOptions

# %%
fb_options = YahooOptions('FB')

# %%
options_df = fb_options.get_options_data(expiry=fb_options.expiry_dates[0])
options_df.head()
# Out:
#                                             Last  ...                                               JSON
# Strike Expiry     Type Symbol                     ...
# 155.0  2021-06-04 put  FB210604P00155000    0.04  ...  {'contractSymbol': 'FB210604P00155000', 'strik...
# 160.0  2021-06-04 put  FB210604P00160000    0.05  ...  {'contractSymbol': 'FB210604P00160000', 'strik...
# 175.0  2021-06-04 put  FB210604P00175000    0.05  ...  {'contractSymbol': 'FB210604P00175000', 'strik...
# 180.0  2021-06-04 put  FB210604P00180000    0.20  ...  {'contractSymbol': 'FB210604P00180000', 'strik...
# 185.0  2021-06-04 call FB210604C00185000  132.40  ...  {'contractSymbol': 'FB210604C00185000', 'strik...
#
# [5 rows x 15 columns]

# %% [markdown]
# # **Quandl**

# %%
# !pip install quandl
import quandl
# Out:
# Requirement already satisfied: quandl in /usr/local/lib/python3.7/dist-packages (3.6.1)
# Requirement already satisfied: requests>=2.7.0 in /usr/local/lib/python3.7/dist-packages (from quandl) (2.23.0)
# Requirement already satisfied: inflection>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from quandl) (0.5.1)
# Requirement already satisfied: pandas>=0.14 in /usr/local/lib/python3.7/dist-packages (from quandl) (1.1.5)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from quandl) (2.8.1)
# Requirement already satisfied: numpy>=1.8 in /usr/local/lib/python3.7/dist-packages (from quandl) (1.19.5)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.7/dist-packages (from quandl) (8.7.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from quandl) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.7.0->quandl) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.7.0->quandl) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.7.0->quandl) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.7.0->quandl) (2020.12.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.14->quandl) (2018.9)

# %%
data = quandl.get('WIKI/AAPL')
data.head()
# Out:
#              Open   High    Low  ...  Adj. Low  Adj. Close  Adj. Volume
# Date                             ...
# 1980-12-12  28.75  28.87  28.75  ...  0.422706    0.422706  117258400.0
# 1980-12-15  27.38  27.38  27.25  ...  0.400652    0.400652   43971200.0
# 1980-12-16  25.37  25.37  25.25  ...  0.371246    0.371246   26432000.0
# 1980-12-17  25.87  26.00  25.87  ...  0.380362    0.380362   21610400.0
# 1980-12-18  26.63  26.75  26.63  ...  0.391536    0.391536   18362400.0
#
# [5 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %matplotlib inline

# %%
data.plot()
